# %%
import scrabble_assistant as sa
from collections import Counter

# %%
# %%timeit
print(sa.get_best_hint_for_empty_board(Counter('собака'))[7])
print(sa.get_best_hint_for_empty_board(Counter('салат'))[7])
print(sa.get_best_hint_for_empty_board(Counter('шалаш'))[7])
print(sa.get_best_hint_for_empty_board(Counter('суп'))[7])
print(sa.get_best_hint_for_empty_board(Counter('абв'))[7])
print(sa.get_best_hint_for_empty_board(Counter('абвг'))[7])
print(sa.get_best_hint_for_empty_board(Counter('абвгд'))[7])
print(sa.get_best_hint_for_empty_board(Counter('абвгде'))[7])
print(sa.get_best_hint_for_empty_board(Counter('абвгдеж'))[7])
print(sa.get_best_hint_for_empty_board(Counter('абвгдежз'))[7])
print(sa.get_best_hint_for_empty_board(Counter('абвгдежзи'))[7])
print(sa.get_best_hint_for_empty_board(Counter('абвгдежзи'))[7])
print(sa.get_best_hint_for_empty_board(Counter('уеаояижзфцшщъыьэю'))[7])
print(sa.get_best_hint_for_empty_board(Counter('аашаш'))[7])
# Out:
# ['', '', '', 'б', 'а', 'с', 'к', 'а', '', '', '', '', '', '', '']
# ['', '', '', 'с', 'а', 'л', 'а', 'т', '', '', '', '', '', '', '']
# ['', '', '', 'ш', 'а', 'л', 'а', 'ш', '', '', '', '', '', '', '']
# ['', '', '', '', '', '', 'с', 'у', 'п', '', '', '', '', '', '']
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['', '', '', '', '', '', 'а', 'д', '', '', '', '', '', '', '']
# ['', '', '', '', '', '', 'б', 'е', 'г', '', '', '', '', '', '']
# ['', '', '', 'в', 'е', 'ж', 'д', 'а', '', '', '', '', '', '', '']
# ['', '', '', 'з', 'а', 'б', 'е', 'г', '', '', '', '', '', '', '']
# ['', '', '', '', '', '', '', 'в', 'и', 'з', 'а', 'ж', '', '', '']
# ['', '', '', '', '', '', '', 'в', 'и', 'з', 'а', 'ж', '', '', '']
# ['', '', '', 'ф', 'а', 'ц', 'и', 'я', '', '', '', '', '', '', '']
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['', '', '', 'б', 'а', 'с', 'к', 'а', '', '', '', '', '', '', '']
# ...

# %% [markdown]
# 1.47 s ± 13.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
